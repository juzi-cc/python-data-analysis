# %% [markdown]
# # 项目：整理Netflix电影演员评分数据

# %% [markdown]
# ## 分析目标

# %% [markdown]
# 此数据分析的目的是，整理不同流派影视作品，比如喜剧片、动作片、科幻片中，各演员出演作品的平均IMDB评分，从而挖掘出各个流派中的高评分作品演员。
#
# 本实战项目的目的在于练习整理数据，从而得到可供下一步分析的数据。

# %% [markdown]
# ## 简介

# %% [markdown]
# 原始数据集记录了截止至2022年7月美国地区可观看的所有Netflix电视剧及电影数据。数据集包含两个数据表：`titles.csv`和`credits.csv`。
#
# `titles.csv`包含电影及电视剧相关信息，包括影视作品ID、标题、类型、描述、流派、IMDB（一个国外的在线评分网站）评分，等等。`credits.csv`包含超过7万名出现在Netflix影视作品的导演及演员信息，包括名字、影视作品ID、人物名、演职员类型（导演/演员）等。

# %% [markdown]
# `titles.csv`每列的含义如下：
# - id：影视作品ID。
# - title：影视作品标题。
# - show_type：作品类型，电视节目或电影。
# - description：简短描述。
# - release_year：发布年份。
# - age_certification：适龄认证。
# - runtime：每集电视剧或电影的长度。
# - genres：流派类型列表。
# - production_countries：出品国家列表。
# - seasons：如果是电视剧，则是季数。
# - imdb_id：IMDB的ID。
# - imdb_score：IMDB的评分。
# - imdb_votes：IMDB的投票数。
# - tmdb_popularity：TMDB的流行度。
# - tmdb_score：TMDB的评分。
#
# `credits.csv`每列的含义如下：
# - person_ID：演职员ID。
# - id：参与的影视作品ID。
# - name：姓名。
# - character_name：角色姓名。
# - role：演职员类型，演员或导演。

# %%
import pandas as pd

# %%
origina_titles = pd.read_csv('10_titles.csv')
original_credits = pd.read_csv('10_credits.csv')

# %%
cleand_titles = origina_titles.copy()
cleand_credits = original_credits.copy()

# %%
cleand_titles.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
#
#   age_certification  runtime                                       genres  \
# 0             TV-MA       51                            ['documentation']
# 1                 R      114                           ['drama', 'crime']
# 2                 R      109  ['drama', 'action', 'thriller', 'european']
# 3                PG       91              ['fantasy', 'action', 'comedy']
# 4               NaN      150                            ['war', 'action']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0               ['US']      1.0        NaN         NaN         NaN
# 1               ['US']      NaN  tt0075314         8.2    808582.0
# 2               ['US']      NaN  tt0068473         7.7    107673.0
# 3               ['GB']      NaN  tt0071853         8.2    534486.0
# 4         ['GB', 'US']      NaN  tt0061578         7.7     72662.0
#
#    tmdb_popularity  tmdb_score
# 0            0.600         NaN
# 1           40.965       8.179
# 2           10.010       7.300
# 3           15.461       7.811
# 4           20.398       7.600

# %%
cleand_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5850 entries, 0 to 5849
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5850 non-null   object
#  1   title                 5849 non-null   object
#  2   type                  5850 non-null   object
#  3   description           5832 non-null   object
#  4   release_year          5850 non-null   int64
#  5   age_certification     3231 non-null   object
#  6   runtime               5850 non-null   int64
#  7   genres                5850 non-null   object
#  8   production_countries  5850 non-null   object
#  9   seasons               2106 non-null   float64
#  10  imdb_id               5447 non-null   object
#  11  imdb_score            5368 non-null   float64
#  12  imdb_votes            5352 non-null   float64
#  13  tmdb_popularity       5759 non-null   float64
#  14  tmdb_score            5539 non-null   float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 685.7+ KB

# %%
cleand_titles[cleand_titles['imdb_score'].isnull()]
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 75     tm132164                       Bill Hicks: Sane Man  MOVIE
# 145    ts251477                            My First Errand   SHOW
# 177    ts224786                                   Escalona   SHOW
# 180      tm8687     Sam Kinison: Family Entertainment Hour  MOVIE
# ...         ...                                        ...    ...
# 5810  tm1225897                                 Social Man  MOVIE
# 5833   ts307884                                 HQ Barbers   SHOW
# 5840  tm1216735                            Sun of the Soil  MOVIE
# 5844  tm1074617              Bling Empire - The Afterparty  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# 75    Sane Man was filmed before Bill recorded ‘Dang...          1989
# 145   “Hajimete no Otsukai” (First Errand) is a Japa...          1991
# 177   The improbable real life of Rafael Escalona, w...          1991
# 180   Get ready to scream with laughter! Sam Kinison...          1991
# ...                                                 ...           ...
# 5810  Two competitive social media Influencers go he...          2021
# 5833  When a family run barber shop in the heart of ...          2021
# 5840  In 14th-century Mali, an ambitious young royal...          2022
# 5844  The stars of "Bling Empire" discuss the show's...          2021
# 5848  Jamie Foxx, David Alan Grier and more from the...          2021
#
#      age_certification  runtime                                  genres  \
# 0                TV-MA       51                       ['documentation']
# 75                   R       80                              ['comedy']
# 145               TV-G       18  ['documentation', 'family', 'reality']
# 177              TV-MA       44                               ['drama']
# 180                NaN       49                              ['comedy']
# ...                ...      ...                                     ...
# 5810               NaN       96                     ['comedy', 'drama']
# 5833             TV-14       24                              ['comedy']
# 5840               NaN       26                                      []
# 5844               NaN       35                                      []
# 5848             PG-13       37                                      []
#
#      production_countries  seasons     imdb_id  imdb_score  imdb_votes  \
# 0                  ['US']      1.0         NaN         NaN         NaN
# 75                 ['US']      NaN         NaN         NaN         NaN
# 145                ['JP']     12.0         NaN         NaN         NaN
# 177                ['CO']      1.0         NaN         NaN         NaN
# 180                ['US']      NaN         NaN         NaN         NaN
# ...                   ...      ...         ...         ...         ...
# 5810                   []      NaN  tt20198164         NaN         NaN
# 5833               ['NG']      1.0         NaN         NaN         NaN
# 5840                   []      NaN         NaN         NaN         NaN
# 5844               ['US']      NaN         NaN         NaN         NaN
# 5848               ['US']      NaN         NaN         NaN         NaN
#
#       tmdb_popularity  tmdb_score
# 0               0.600         NaN
# 75              3.377         7.5
# 145             7.730         7.8
# 177             7.352         7.6
# 180             1.840         6.1
# ...               ...         ...
# 5810              NaN         NaN
# 5833            0.840         NaN
# 5840            1.179         7.0
# 5844              NaN         NaN
# 5848            1.296        10.0
#
# [482 rows x 15 columns]

# %%
cleand_titles.dropna(subset = ['imdb_score'], inplace = True)

# %%
cleand_titles['imdb_score'].isnull().sum()
# Out:
# 0

# %%
cleand_titles['id'].duplicated().sum()
# Out:
# 0

# %%
cleand_titles[''] = cleand_titles['genres'].str.split(',', expand=True)
# Out:
#                0             1            2             3     4     5     6  \
# 1       ['drama'      'crime']         None          None  None  None  None
# 2       ['drama'      'action'   'thriller'   'european']  None  None  None
# 3     ['fantasy'      'action'    'comedy']          None  None  None  None
# 4         ['war'     'action']         None          None  None  None  None
# 5      ['comedy'   'european']         None          None  None  None  None
# ...          ...           ...          ...           ...   ...   ...   ...
# 5843  ['romance'      'comedy'     'drama']          None  None  None  None
# 5845  ['romance'      'drama']         None          None  None  None  None
# 5846   ['drama']          None         None          None  None  None  None
# 5847  ['comedy']          None         None          None  None  None  None
# 5849   ['family'   'animation'    'comedy']          None  None  None  None
#
#          7     8     9
# 1     None  None  None
# 2     None  None  None
# 3     None  None  None
# 4     None  None  None
# 5     None  None  None
# ...    ...   ...   ...
# 5843  None  None  None
# 5845  None  None  None
# 5846  None  None  None
# 5847  None  None  None
# 5849  None  None  None
#
# [5368 rows x 10 columns]

# %%
cleand_titles['genres'].value_counts()
# Out:
# genres
# ['comedy']                                                       436
# ['drama']                                                        272
# ['documentation']                                                261
# ['comedy', 'drama']                                              123
# ['drama', 'romance']                                             121
#                                                                 ...
# ['drama', 'war', 'action', 'thriller', 'history', 'european']      1
# ['thriller', 'crime', 'drama', 'western']                          1
# ['drama', 'scifi', 'fantasy', 'horror']                            1
# ['horror', 'fantasy', 'thriller']                                  1
# ['documentation', 'music', 'reality']                              1
# Name: count, Length: 1695, dtype: int64

# %%
cleand_titles.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   5368.000000  5368.000000  1939.000000  5368.000000  5.352000e+03
# mean    2016.298994    78.562407     2.232078     6.510861  2.343938e+04
# std        7.005642    38.711435     2.769952     1.163826  9.582047e+04
# min     1954.000000     0.000000     1.000000     1.500000  5.000000e+00
# 25%     2016.000000    45.000000     1.000000     5.800000  5.167500e+02
# 50%     2018.000000    86.000000     1.000000     6.600000  2.233500e+03
# 75%     2020.000000   105.000000     2.500000     7.300000  9.494000e+03
# max     2022.000000   225.000000    42.000000     9.600000  2.294231e+06
#
#        tmdb_popularity   tmdb_score
# count      5293.000000  5145.000000
# mean         23.471931     6.823868
# std          84.058311     1.145812
# min           0.600000     1.000000
# 25%           2.939000     6.100000
# 50%           7.175000     6.900000
# 75%          17.211000     7.500000
# max        2274.044000    10.000000

# %%
cleand_credits.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
cleand_credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77801 entries, 0 to 77800
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   person_id  77801 non-null  int64
#  1   id         77801 non-null  object
#  2   name       77801 non-null  object
#  3   character  68029 non-null  object
#  4   role       77801 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.0+ MB
